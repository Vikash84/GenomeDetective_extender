# %% [markdown]
# ## Testing heatmaps for the visualisation of Genome Detective output
#
# Date: 2018-05-15
# Author: Sam Nooij

# %%
import numpy as np
import pandas as pd
from bokeh.plotting import figure, show, output_file
from bokeh.models import HoverTool, ColumnDataSource
from bokeh.sampledata.les_mis import data

#Try these as test input
input_file = "../results/3_1_results.csv"
input_df = pd.read_csv(input_file)

#Check if the correct file was imported:
input_df
# Out:
#               Assignment  # Contigs  Mapped # Reads  Coverage (%)  \
# 0              Norovirus        1.0          542592     99.827082
# 1  uncultured crAssphage       12.0           78949     78.068305
#
#    Mapped depth <br/>of Coverage  NT Identity (%)  AA Identity (%)  \
# 0                        11929.1          79.3604          84.7965
# 1                          171.9          96.3036          95.3261
#
#                                              Contigs
# 0  >1_20682_AAGAGGCACCTAGAGT_L001_R1_001_00000000...
# 1  >1_20682_AAGAGGCACCTAGAGT_L001_R1_001_00000000...

# %%
samples = ["Run3-sample1"]
assignments = list(input_df['Assignment'])
data = input_df

colors = ["#550000"]
#The current colour is dark red or brownish, like the faeces from which we sequenced viruses

assignment = []
sample = []
color = []
load = []
alpha = []

for s in samples:
    for a in assignments:
        assignment.append(a)
        sample.append(s)
        current_load = data["Mapped # Reads"][len(assignment) - 1]
        load.append(data["Mapped # Reads"][len(assignment) - 1])
        color.append(colors[0])
        max_load = max(data["Mapped # Reads"])
        alpha.append(min(current_load / float(max_load), 0.9) + 0.1)
        #let the alpha be the fraction of the highest read count ("max_load")
        
source = ColumnDataSource(
         data = dict(assignment=assignment, sample=sample, color=color, load=load, alpha=alpha)
)

output_notebook()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-eefc7fa25eba> in <module>()
#      27 )
#      28
# ---> 29 output_notebook()
#
# NameError: name 'output_notebook' is not defined

# %%
TOOLS = "hover, save, pan, box_zoom, wheel_zoom, reset"

p = figure(title = "Viruses in run 3-1, classified by Genome Detective",
          x_range = list(samples),
          y_range = list(reversed(assignments)), #reverse to order 'from top to bottom'
          x_axis_location = "above",
          toolbar_location="right",
          tools = TOOLS)

p.plot_width = 500
p.plot_height = 500
p.grid.grid_line_color = None
p.axis.axis_line_color = None
p.axis.major_tick_line_color = None
p.axis.major_label_text_font_size = "10pt"
p.title_text_font_size = "14pt"
p.axis.major_label_standoff = 0
p.xaxis.major_label_orientation = np.pi/3

p.rect("sample", "assignment", 1, 1, source=source,
       color="color", alpha="alpha", line_color=None)

p.select_one(HoverTool).tooltips = [
    ('Sample', "@sample"),
    ('Taxon' , "@assignment"),
    ('Number of reads', "@load"),
]

#output_file('heatmap_test.html', title="Testing Genome Detective heatmaps in Jupyter+Bokeh")

show(p)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-95f10cdaa9b0> in <module>()
#      14 p.axis.major_tick_line_color = None
#      15 p.axis.major_label_text_font_size = "10pt"
# ---> 16 p.title_text_font_size = "14pt"
#      17 p.axis.major_label_standoff = 0
#      18 p.xaxis.major_label_orientation = np.pi/3
#
# /software/python/anaconda2/envs/panbio/lib/python2.7/site-packages/bokeh/core/has_props.pyc in __setattr__(self, name, value)
#     269
#     270             raise AttributeError("unexpected attribute '%s' to %s, %s attributes are %s" %
# --> 271                 (name, self.__class__.__name__, text, nice_join(matches)))
#     272
#     273     def __str__(self):
#
# AttributeError: unexpected attribute 'title_text_font_size' to Figure, possible attributes are above, aspect_scale, background_fill_alpha, background_fill_color, below, border_fill_alpha, border_fill_color, css_classes, disabled, extra_x_ranges, extra_y_ranges, h_symmetry, height, hidpi, inner_height, inner_width, js_event_callbacks, js_property_callbacks, layout_height, layout_width, left, lod_factor, lod_interval, lod_threshold, lod_timeout, match_aspect, min_border, min_border_bottom, min_border_left, min_border_right, min_border_top, name, outline_line_alpha, outline_line_cap, outline_line_color, outline_line_dash, outline_line_dash_offset, outline_line_join, outline_line_width, output_backend, plot_height, plot_width, renderers, right, sizing_mode, subscribed_events, tags, title, title_location, toolbar, toolbar_location, toolbar_sticky, v_symmetry, width, x_range, x_scale, y_range or y_scale

# %% [markdown]
# ## Expand to more samples

# %%
import glob

file_list = glob.glob("../results/*_results.csv")
file_list = sorted(file_list)

#Collect a list of run numbers and sample numbers
sample_ids = []

for file_path in file_list:
    file_name = file_path.split('/')[-1]
    sample_id = file_name[:file_name.index("_results.csv")]
    run_id = sample_id.split('_')[0]
    sample_number = sample_id.split('_')[1:]
    if type(sample_number) == type(["list"]):
        sample_number = '_'.join(sample_number)
    else:
        pass
    #If there are multiple parts to a sample number, separated by an underscore,
    # it is now turned from a list into a string.
    sample_ids.append("%s-%s" % (run_id, sample_number))
    
sample_ids = sorted(sample_ids)

#In case I need a link between the file names and the IDs as I stored them now:
id_mapping = {}

for index in xrange(0, len(sample_ids)):
    id_mapping[sample_ids[index]] = file_list[index]
    
print id_mapping
# Out:
# {'5-5061600092_S2': '../results/5_5061600092_S2_results.csv', '4-D': '../results/4_D_results.csv', '3-1': '../results/3_1_results.csv', '6-A1': '../results/6_A1_results.csv'}

# %% [markdown]
# ### Create separate heatmaps for multiple result csv files

# %%
for results_file in file_list:
    results_df = pd.read_csv(results_file)
    
    samples = [results_file]
    assignments = list(results_df['Assignment'])
    data = results_df
    
    colors = ["#550000"]
    #The current colour is dark red or brownish, like the faeces from which we sequenced viruses

    assignment = []
    sample = []
    color = []
    load = []
    alpha = []

    for s in samples:
        for a in assignments:
            assignment.append(a)
            sample.append(s)
            current_load = data["Mapped # Reads"][len(assignment) - 1]
            load.append(data["Mapped # Reads"][len(assignment) - 1])
            color.append(colors[0])
            max_load = max(data["Mapped # Reads"])
            alpha.append(min(current_load / float(max_load), 0.9) + 0.1)
            #let the alpha be the fraction of the highest read count ("max_load")

    source = ColumnDataSource(
             data = dict(assignment=assignment, sample=sample, color=color, load=load, alpha=alpha)
    )
    
    TOOLS = "hover, save, pan, box_zoom, wheel_zoom, reset"

    p = figure(title = "Viruses classified by Genome Detective",
              x_range = list(samples),
              y_range = list(reversed(assignments)), #reverse to order 'from top to bottom'
              x_axis_location = "above",
              toolbar_location="right",
              tools = TOOLS)

    p.plot_width = 500
    p.plot_height = 400
    p.grid.grid_line_color = None
    p.axis.axis_line_color = None
    p.axis.major_tick_line_color = None
    p.axis.major_label_text_font_size = "10pt"
    p.title_text_font_size = "14pt"
    p.axis.major_label_standoff = 0
    p.xaxis.major_label_orientation = np.pi/3

    p.rect("sample", "assignment", 1, 1, source=source,
           color="color", alpha="alpha", line_color=None)

    p.select_one(HoverTool).tooltips = [
        ('Sample', "@sample"),
        ('Taxon' , "@assignment"),
        ('Number of reads', "@load"),
    ]

    #output_file('heatmap_test.html', title="Testing Genome Detective heatmaps in Jupyter+Bokeh")

    show(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e9da6e41cd3e> in <module>()
#       1 for results_file in file_list:
# ----> 2     results_df = pd.read_csv(results_file)
#       3
#       4     samples = [results_file]
#       5     assignments = list(results_df['Assignment'])
#
# NameError: name 'pd' is not defined

# %%
import glob

def create_concatenated_dataframe(file_wildcard, folder):
    """
    Input: a filename with wildcard,
            and a folder name
    Output: One concatenated dataframe of all the input files
    """
    #Step 1: create a list of the files using glob
    file_list = glob.glob("%s%s" % (folder, file_wildcard))
    file_list = sorted(file_list)
    
    file_suffix = file_wildcard.lstrip("*")
    
    #Step 2: open the files as dataframe, remove "Contigs" column and add sample IDs
    
    df_list = []
    for results_file in file_list:
        results_df = pd.read_csv(results_file)
        results_df = results_df.drop("Contigs", axis = 1) #remove unnecessary (and long!) column
        sample_id = results_file[:results_file.index(file_suffix)].split('/')[-1]
        results_df["sample"] = sample_id
        df_list.append(results_df)

    #Step 3: concatenate the dataframes
    super_df = pd.concat(df_list, ignore_index=True)
    
    return(super_df)

assignment_df = create_concatenated_dataframe(file_wildcard = "*_results.csv", folder = "../results/")
# Out:
#                   Assignment  # Contigs  Mapped # Reads  Coverage (%)  \
# 0                  Norovirus        1.0          542592     99.827082
# 1      uncultured crAssphage       12.0           78949     78.068305
# 2                  Norovirus        1.0            5541    100.914554
# 3   Pepper mild mottle virus        3.0             157     74.123014
# 4                  Norovirus        1.0         4599864     99.960096
# 5             Parechovirus A        1.0         1707242     98.557431
# 6               Equartevirus        1.0           83629     99.448992
# 7              Enterovirus B        1.0            2304     89.822709
# 8              Enterovirus A        1.0         1212499     99.487387
# 9                  Norovirus        1.0          257515    100.705513
# 10            Parechovirus A        1.0           94027     99.523680
# 11             Enterovirus B        3.0             246     61.347950
# 12  Escherichia virus phiV10        5.0            1124     55.735986
#
#     Mapped depth <br/>of Coverage  NT Identity (%)  AA Identity (%)  \
# 0                         11929.1          79.3604          84.7965
# 1                           171.9          96.3036          95.3261
# 2                           112.6          67.6592          74.0047
# 3                             5.2          97.4533          98.3850
# 4                         36725.5          77.4850          86.3419
# 5                         14144.5          77.9067          88.3486
# 6                           397.2         100.0000          99.9836
# 7                            20.8          64.9842          82.3960
# 8                         27455.9          77.1119          90.1550
# 9                          5579.3          68.0332          74.2656
# 10                         2147.2          76.0974          84.9472
# 11                            9.1          73.0863          86.9505
# 12                            8.6          98.5364          98.7055
#
#              sample
# 0               3_1
# 1               3_1
# 2               4_D
# 3               4_D
# 4   5_5061600092_S2
# 5   5_5061600092_S2
# 6   5_5061600092_S2
# 7   5_5061600092_S2
# 8              6_A1
# 9              6_A1
# 10             6_A1
# 11             6_A1
# 12             6_A1

# %%
samples = list(assignment_df["sample"])
assignments = list(assignment_df['Assignment'])
loads = list(assignment_df["Mapped # Reads"])

colors = ["#550000"]
#The current colour is dark red or brownish, like the faeces from which we sequenced viruses

max_load = max(loads)
alphas = [ min( x / float(max_load), 0.9) + 0.1 for x in loads]

source = ColumnDataSource(
         data = dict(samples=samples, assignments=assignments, colors=colors, loads=loads, alphas=alphas)
)

output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="aaf5b1ec-f063-41e3-9cfb-05b40fc49544">Loading BokehJS ...</span>
#     </div>

# %%
TOOLS = "hover, save, pan, box_zoom, wheel_zoom, reset"

p = figure(title = "Viruses classified by Genome Detective",
          x_range = list(sorted(set(samples))),
          y_range = list(reversed(sorted(set(assignments)))), #reverse to order 'from top to bottom'
          x_axis_location = "above",
          toolbar_location="right",
          tools = TOOLS)

p.plot_width = 800
p.plot_height = 600
p.grid.grid_line_color = None
p.axis.axis_line_color = None
p.axis.major_tick_line_color = None
p.axis.major_label_text_font_size = "12pt"
p.title_text_font_size = "16pt"
p.axis.major_label_standoff = 0
p.xaxis.major_label_orientation = np.pi/4

p.rect("samples", "assignments", 1, 1, source=source,
       color="colors", alpha="alphas", line_color=None)

p.select_one(HoverTool).tooltips = [
    ('Sample', "@samples"),
    ('Taxon' , "@assignments"),
    ('Number of reads', "@loads"),
]

output_file('../results/Assignment_heatmap.html', title="Genome Detective classified viruses")

show(p)
# Out:
#     <div class="plotdiv" id="ad3b9b72-1c6b-4c56-9de4-c13351e32296"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ad3b9b72-1c6b-4c56-9de4-c13351e32296");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ad3b9b72-1c6b-4c56-9de4-c13351e32296' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5ff497c3-e971-415d-85fa-5582aee3bd02":{"roots":{"references":[{"attributes":{"plot":{"id":"e0b9f83e-17bc-4496-95bf-87262c5bbb29","subtype":"Figure","type":"Plot"}},"id":"e3bf6709-b2d5-4cb7-898b-ab4c179e9341","type":"ResetTool"},{"attributes":{"overlay":{"id":"96acecaf-6e59-408b-8503-1234ab5ae257","type":"BoxAnnotation"},"plot":{"id":"a361e7cd-330d-4674-a8f0-2adb62d8c983","subtype":"Figure","type":"Plot"}},"id":"da4308f8-8917-4da1-9398-3809418dacc2","type":"BoxZoomTool"},{"attributes":{},"id":"86857637-f199-48f1-b469-b9200bbe2862","type":"CategoricalTicker"},{"attributes":{"above":[{"id":"ccb384e5-653a-4049-944f-2a3fa6497f3a","type":"CategoricalAxis"}],"left":[{"id":"24c7f1ad-efa9-4d0a-999e-dd7066adb2b0","type":"CategoricalAxis"}],"plot_height":400,"plot_width":500,"renderers":[{"id":"ccb384e5-653a-4049-944f-2a3fa6497f3a","type":"CategoricalAxis"},{"id":"9b0168ce-5cc7-4483-9f26-a076077feed9","type":"Grid"},{"id":"24c7f1ad-efa9-4d0a-999e-dd7066adb2b0","type":"CategoricalAxis"},{"id":"f0bf4e53-f6d4-4614-844c-207d5f23f72f","type":"Grid"},{"id":"cce9ef30-bc95-47a5-9cef-be02be577730","type":"BoxAnnotation"},{"id":"b15d1005-b291-4d39-b141-db197795c115","type":"GlyphRenderer"}],"title":"Viruses classified by Genome Detective","title_text_font_size":{"value":"14pt"},"tool_events":{"id":"24b0d586-520d-48e8-9a08-d1d0c4c81701","type":"ToolEvents"},"toolbar_location":"right","tools":[{"id":"3f501023-f7d2-40cc-b10f-f21daba11ada","type":"HoverTool"},{"id":"741ca145-88d1-4cbd-9133-09f9a30ff8b5","type":"PreviewSaveTool"},{"id":"c73df229-3ad2-4715-8261-8ab063cf66a2","type":"PanTool"},{"id":"5297a3ad-65d8-45f4-8808-4965b6314cc2","type":"BoxZoomTool"},{"id":"9b7d9f00-f4f3-4a8f-9dfb-c1a561627b40","type":"WheelZoomTool"},{"id":"ce919077-bb89-4830-8a0b-ad48cfa2543a","type":"ResetTool"}],"x_range":{"id":"0f02a531-a094-47e0-b0c2-e05f99d508ec","type":"FactorRange"},"y_range":{"id":"2eaff61f-a42c-410e-9362-334dd69529a9","type":"FactorRange"}},"id":"32d14eec-1f31-4e4d-a093-fda53c773d5b","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"8070569a-d842-4033-b833-84bec86242a6","subtype":"Figure","type":"Plot"}},"id":"e5046c2c-3fc2-419f-a7a4-f04d4304d879","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"dc791fab-d02e-4987-abd8-7172313da6d6","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"data","value":1},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"data","value":1},"x":{"field":"samples"},"y":{"field":"assignments"}},"id":"a115e27d-e238-4cbf-8b97-6184ed50fbc0","type":"Rect"},{"attributes":{},"id":"602a785e-3b2f-43f1-a41c-c03a2d3c8017","type":"CategoricalTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"data","value":1},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"data","value":1},"x":{"field":"samples"},"y":{"field":"assignments"}},"id":"f5eb6a25-dce1-4962-8f20-bc3b076b2cad","type":"Rect"},{"attributes":{},"id":"80c7c982-66a5-452b-abfc-52373fc3d84c","type":"CategoricalTicker"},{"attributes":{},"id":"87de2ef8-fca5-4f5e-a425-7ee14dd4b498","type":"CategoricalTicker"},{"attributes":{"plot":{"id":"cdaf6064-ba98-4b97-b040-9da078981004","subtype":"Figure","type":"Plot"}},"id":"695696fa-d26d-4186-ab6e-62bea3e95243","type":"ResetTool"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"468282c7-f669-4ae1-adc4-ab803eb2f0a1","subtype":"Figure","type":"Plot"},"ticker":{"id":"44f57504-b80d-450b-8b9d-9fdd6420f546","type":"CategoricalTicker"}},"id":"42c95255-c591-4d4b-8225-bebd80cac2fc","type":"Grid"},{"attributes":{"plot":{"id":"40ebabff-3 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[101]</strong>&gt;</code></p>

# %%
discovery_df = create_concatenated_dataframe(file_wildcard="*_discovery.csv", folder = "../results/")

samples = list(discovery_df["sample"])
assignments = list(discovery_df['Assignment'])
loads = list(discovery_df["Mapped # Reads"])

colors = ["#550000"]
#The current colour is dark red or brownish, like the faeces from which we sequenced viruses

max_load = max(loads)
alphas = [ min( x / float(max_load), 0.9) + 0.1 for x in loads]

source = ColumnDataSource(
         data = dict(samples=samples, assignments=assignments, colors=colors, loads=loads, alphas=alphas)
)

TOOLS = "hover, save, pan, box_zoom, wheel_zoom, reset"

p = figure(title = "Viruses discovered by Genome Detective",
          x_range = list(sorted(set(samples))),
          y_range = list(reversed(sorted(set(assignments)))), #reverse to order 'from top to bottom'
          x_axis_location = "above",
          toolbar_location="right",
          tools = TOOLS)

p.plot_width = 800
p.plot_height = 800
p.grid.grid_line_color = None
p.axis.axis_line_color = None
p.axis.major_tick_line_color = None
p.axis.major_label_text_font_size = "12pt"
p.title_text_font_size = "16pt"
p.axis.major_label_standoff = 0
p.xaxis.major_label_orientation = np.pi/4

p.rect("samples", "assignments", 1, 1, source=source,
       color="colors", alpha="alphas", line_color=None)

p.select_one(HoverTool).tooltips = [
    ('Sample', "@samples"),
    ('Taxon' , "@assignments"),
    ('Number of reads', "@loads"),
]

output_file('../results/Discovery_heatmap.html', title="Genome Detective discovered viruses")

show(p)
# Out:
#     <div class="plotdiv" id="14fdd2b3-aa59-4646-89c9-68929046b4c4"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("14fdd2b3-aa59-4646-89c9-68929046b4c4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '14fdd2b3-aa59-4646-89c9-68929046b4c4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"248bab54-937a-43d5-b21f-cceedf9f088b":{"roots":{"references":[{"attributes":{"overlay":{"id":"96acecaf-6e59-408b-8503-1234ab5ae257","type":"BoxAnnotation"},"plot":{"id":"a361e7cd-330d-4674-a8f0-2adb62d8c983","subtype":"Figure","type":"Plot"}},"id":"da4308f8-8917-4da1-9398-3809418dacc2","type":"BoxZoomTool"},{"attributes":{"above":[{"id":"ccb384e5-653a-4049-944f-2a3fa6497f3a","type":"CategoricalAxis"}],"left":[{"id":"24c7f1ad-efa9-4d0a-999e-dd7066adb2b0","type":"CategoricalAxis"}],"plot_height":400,"plot_width":500,"renderers":[{"id":"ccb384e5-653a-4049-944f-2a3fa6497f3a","type":"CategoricalAxis"},{"id":"9b0168ce-5cc7-4483-9f26-a076077feed9","type":"Grid"},{"id":"24c7f1ad-efa9-4d0a-999e-dd7066adb2b0","type":"CategoricalAxis"},{"id":"f0bf4e53-f6d4-4614-844c-207d5f23f72f","type":"Grid"},{"id":"cce9ef30-bc95-47a5-9cef-be02be577730","type":"BoxAnnotation"},{"id":"b15d1005-b291-4d39-b141-db197795c115","type":"GlyphRenderer"}],"title":"Viruses classified by Genome Detective","title_text_font_size":{"value":"14pt"},"tool_events":{"id":"24b0d586-520d-48e8-9a08-d1d0c4c81701","type":"ToolEvents"},"toolbar_location":"right","tools":[{"id":"3f501023-f7d2-40cc-b10f-f21daba11ada","type":"HoverTool"},{"id":"741ca145-88d1-4cbd-9133-09f9a30ff8b5","type":"PreviewSaveTool"},{"id":"c73df229-3ad2-4715-8261-8ab063cf66a2","type":"PanTool"},{"id":"5297a3ad-65d8-45f4-8808-4965b6314cc2","type":"BoxZoomTool"},{"id":"9b7d9f00-f4f3-4a8f-9dfb-c1a561627b40","type":"WheelZoomTool"},{"id":"ce919077-bb89-4830-8a0b-ad48cfa2543a","type":"ResetTool"}],"x_range":{"id":"0f02a531-a094-47e0-b0c2-e05f99d508ec","type":"FactorRange"},"y_range":{"id":"2eaff61f-a42c-410e-9362-334dd69529a9","type":"FactorRange"}},"id":"32d14eec-1f31-4e4d-a093-fda53c773d5b","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"48d9abc5-9717-49f7-83db-bf7a784a5561","subtype":"Figure","type":"Plot"}},"id":"b4d5300c-5674-43af-ab4b-ea54866d4d8f","type":"PreviewSaveTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"dc791fab-d02e-4987-abd8-7172313da6d6","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"data","value":1},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"data","value":1},"x":{"field":"samples"},"y":{"field":"assignments"}},"id":"a115e27d-e238-4cbf-8b97-6184ed50fbc0","type":"Rect"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"data","value":1},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"data","value":1},"x":{"field":"samples"},"y":{"field":"assignments"}},"id":"f5eb6a25-dce1-4962-8f20-bc3b076b2cad","type":"Rect"},{"attributes":{},"id":"87de2ef8-fca5-4f5e-a425-7ee14dd4b498","type":"CategoricalTicker"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"468282c7-f669-4ae1-adc4-ab803eb2f0a1","subtype":"Figure","type":"Plot"},"ticker":{"id":"44f57504-b80d-450b-8b9d-9fdd6420f546","type":"CategoricalTicker"}},"id":"42c95255-c591-4d4b-8225-bebd80cac2fc","type":"Grid"},{"attributes":{"plot":{"id":"40ebabff-322e-4910-9932-6af10719e864","subtype":"Figure","type":"Plot"}},"id":"10fdc342-9f41-45dd-8371-af5a108e5733","type":"WheelZoomTool"},{"attributes":{"axis_line_color":{"value":null},"formatter":{"id":"b3fdd2da-8928-4587-b071-c415cd4dcea7","type":"CategoricalTickFormatter"},"major_label_standoff":0,"major_tick_line_color":{"value":null},"plot":{"id":"50a35f25-478c-484e-b410-4b1e1d6814a8","subtype":"Figure","type":"Plot"},"ticker":{"id":"9809b61d-c2bb-44c9-bf57-40b1bbf2f325","type":"CategoricalTicker"}},"id":"2a0b03e8-35f5-4daf-9cbc-132dc1969de6","type":"CategoricalAxis"},{"attributes":{},"id":"f ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[98]</strong>&gt;</code></p>

# %%
# ?output_notebook()

# %%
# Out:
# '_discovery.csv'

# %% [markdown]
# ### A little, simple example of Bokeh plotting, just to check if it works at all
# https://bokeh.pydata.org/en/0.11.1/docs/user_guide/notebook.html

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

N = 4000
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5
colors = ["#%02x%02x%02x" % (r, g, 150) for r, g in zip(np.floor(50+2*x), np.floor(30+2*y))]

output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2403cbc0-65b8-4a21-acdd-07521e8dd3f7">Loading BokehJS ...</span>
#     </div>

# %%
p = figure()
p.circle(x, y, radius=radii, fill_color=colors, fill_alpha=0.6, line_color=None)

# %%
show(p)
# Out:
#     <div class="plotdiv" id="3eee2b8e-0a51-40e4-8110-52d61d46b621"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3eee2b8e-0a51-40e4-8110-52d61d46b621");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3eee2b8e-0a51-40e4-8110-52d61d46b621' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"b6824de1-9f38-47c7-bf43-0ba0dd748121":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["load","alpha","sample","color","assignment"],"data":{"alpha":[1.0,0.24550343536211372],"assignment":["Norovirus","uncultured crAssphage"],"color":["#550000","#550000"],"load":[542592,78949],"sample":["Run3-sample1","Run3-sample1"]}},"id":"79555731-0885-49d1-986e-704509af6e20","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"620ef0e3-85a2-45ca-8796-f52a32ff8fc4","subtype":"Figure","type":"Plot"}},"id":"9ba83b3c-a399-4b89-8c83-91cb475e4a22","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"620ef0e3-85a2-45ca-8796-f52a32ff8fc4","subtype":"Figure","type":"Plot"}},"id":"9dee7061-ea55-439c-a600-287a079854e4","type":"ResetTool"},{"attributes":{"callback":null},"id":"b2657554-02cf-4b87-b6fd-f218abe34dc3","type":"DataRange1d"},{"attributes":{"formatter":{"id":"c18f6791-6563-426e-a443-fb6f2ac162cf","type":"BasicTickFormatter"},"plot":{"id":"0e224f19-be7c-4477-bd86-5a7ef4d4ea5f","subtype":"Figure","type":"Plot"},"ticker":{"id":"4fc60f71-c867-42cf-b10b-3feb7a3a6916","type":"BasicTicker"}},"id":"a08e6edf-39fc-49a1-884b-d59e71693e2e","type":"LinearAxis"},{"attributes":{},"id":"c18f6791-6563-426e-a443-fb6f2ac162cf","type":"BasicTickFormatter"},{"attributes":{},"id":"a4484d6e-d808-48c3-8c6e-944768eab871","type":"ToolEvents"},{"attributes":{"plot":{"id":"620ef0e3-85a2-45ca-8796-f52a32ff8fc4","subtype":"Figure","type":"Plot"}},"id":"c27ff9dd-a7e3-4b01-b86b-928846cc0ecb","type":"PanTool"},{"attributes":{},"id":"e9560bb6-d356-4c00-a31d-b18246425758","type":"CategoricalTickFormatter"},{"attributes":{"axis_line_color":{"value":null},"formatter":{"id":"9bffcf00-76e7-4c39-8029-102334e14602","type":"CategoricalTickFormatter"},"major_label_standoff":0,"major_tick_line_color":{"value":null},"plot":{"id":"cdaf6064-ba98-4b97-b040-9da078981004","subtype":"Figure","type":"Plot"},"ticker":{"id":"2faa61c8-5afb-43ad-a446-4ae5d0db3fd6","type":"CategoricalTicker"}},"id":"5a200265-08f9-4bb6-b5af-fd225376107f","type":"CategoricalAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"9d5f81b3-e7c3-405a-b442-1d0a6cb443d1","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"79555731-0885-49d1-986e-704509af6e20","type":"ColumnDataSource"},"glyph":{"id":"bc2e6b64-0b2e-4e91-825d-846b4efe5398","type":"Rect"},"hover_glyph":null,"nonselection_glyph":{"id":"fe5c06b3-7809-4107-8f6b-e34f1feee09a","type":"Rect"},"selection_glyph":null},"id":"e353f480-183c-46ab-adc8-3ac5c7c1142d","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"0e224f19-be7c-4477-bd86-5a7ef4d4ea5f","subtype":"Figure","type":"Plot"},"ticker":{"id":"4fc60f71-c867-42cf-b10b-3feb7a3a6916","type":"BasicTicker"}},"id":"cd12183d-eea0-4151-bfba-ca4052857cd6","type":"Grid"},{"attributes":{"plot":{"id":"0e224f19-be7c-4477-bd86-5a7ef4d4ea5f","subtype":"Figure","type":"Plot"}},"id":"64c8eb66-5fac-475b-ae1f-3368fd20be3d","type":"ResetTool"},{"attributes":{"data_source":{"id":"7fe012b4-ba13-4c40-965d-a2764ecf3ab9","type":"ColumnDataSource"},"glyph":{"id":"266f8e82-a38e-46ce-93dd-44116ce3edc0","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"ae898c13-11e0-4719-91f5-7c6245234b75","type":"Circle"},"selection_glyph":null},"id":"85d069b1-468a-4e4c-9bc7-61baf282cd47","type":"GlyphRenderer"},{"attributes":{"axis_line_color":{"value":null},"formatter":{"id":"51b7a6bf-1067-4d9b-b6b2-2b4252b28154","type":"CategoricalTickFormatter"},"major_label_orientation":1.0471975511965976,"major_label_standoff":0,"major_tick_line_color":{"value":null},"plot":{"id":"620ef0e3-85a2-45ca-8796-f52a32ff8fc4","subtype":"Figure","type":"Plot"},"ticker":{"id":"6337c4cc-563b-466d-9ed9-bdeb1f6139cf","type":"Categ ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[9]</strong>&gt;</code></p>
